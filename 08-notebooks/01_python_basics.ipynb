# %%
print("Welcome to my AI Solutions Workspace!")
# Out:
# Welcome to my AI Solutions Workspace!

# %%
name = "Benjamin"

print(name)
# Out:
# Benjamin

# %%
numbers = [1,2,3,4,5]

for n in numbers:
    print(n)
# Out:
# 1
# 2
# 3
# 4
# 5
