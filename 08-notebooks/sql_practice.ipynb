# %%
sql_practice.ipynb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sql_practice.ipynb
#
# NameError: name 'sql_practice' is not defined
