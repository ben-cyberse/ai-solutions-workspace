# %%
02_variables.ipynb
# Out:
#   Cell In[1], line 1
#     02_variables.ipynb
#       ^
# SyntaxError: invalid decimal literal

# %%
03_data_types.ipynb
# Out:
#   Cell In[2], line 1
#     03_data_types.ipynb
#       ^
# SyntaxError: invalid decimal literal
