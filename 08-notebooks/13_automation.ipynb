# %%
13_automation.ipynb
# Out:
#   Cell In[1], line 1
#     13_automation.ipynb
#       ^
# SyntaxError: invalid decimal literal

# %%
01_python_basics.ipynb
# Out:
#   Cell In[2], line 1
#     01_python_basics.ipynb
#       ^
# SyntaxError: invalid decimal literal

# %%
01_python_basics.ipynb
# Out:
#   Cell In[3], line 1
#     01_python_basics.ipynb
#       ^
# SyntaxError: invalid decimal literal
